# %%
cart = ["Laptop", "Mouse", "Keyboard"]

cart.append("Monitor")
print(cart)

cart.remove("Mouse")
print(cart)

print(len(cart))
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor']
# ['Laptop', 'Keyboard', 'Monitor']
# 3

# %%
Seat = ["A1", "A2", "A4", "A5"]
Seat.insert(2, "A3")
print(Seat)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5']

# %%
orders=["burger", "pizza", "Noodles"]
orders.pop()
print(orders)
# Out:
# ['burger', 'pizza']

# %%
inventory = ['dc','fgf','efdf','ytt','grg']
inventory.sort()
print(inventory)

inventory.reverse()
print(inventory)
# Out:
# ['dc', 'efdf', 'fgf', 'grg', 'ytt']
# ['ytt', 'grg', 'fgf', 'efdf', 'dc']

# %%
students = ["Amit", "Neha", "Rahul", "Priya"]
backup = students.copy()

backup.append("Rohan")
backup.remove("Neha")

if students == backup:
    print("Same database")
else:
    print("Different databse")
# Out:
# Original and Backup databases are different.

# %%
contacts = ['rahul','aman','rahul','neha','anshu']
contacts.index('aman')
contacts.count('rahul')
# Out:
# 2

# %%
alerts=['fire','danger','stay away']
alerts.clear()
print(alerts)
# Out:
# []

# %%
playlist1=['song1','song2','song3']
playlist2=['song2','song4','song5']
playlist1.extend(playlist2)
print(playlist1)
# Out:
# ['song1', 'song2', 'song3', 'song2', 'song4', 'song5']
# ['song2', 'song4', 'song5']

# %%
numbers=[10,20]
numbers.extend([30,40])
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
#Library management system 

library = ['Lupin','Arsene','True Detective', 'The Gentleman thief']
print(library)

library.append("Matermind")
print(library)

#Search
book = "Arsene"
if book in library:
    print(f"'{book}' is available in the library.")
else:
    print(f"'{book}' is not available.")

#issue
book = "Lupin"
if book in library:
    library.remove(book)
    print(f"'{book}' has been issued.")
else:
    print(f"'{book}' is not available.")

print("Library After Issuing:", library)

library.append("Lupin")
print(library)

backup_library = library.copy()
print(backup_library)

library.sort()
print(library) 5
# Out:
# ['Lupin', 'Arsene', 'True Detective', 'The Gentleman thief']
# ['Lupin', 'Arsene', 'True Detective', 'The Gentleman thief', 'Matermind']
# 'Arsene' is available in the library.
# 'Lupin' has been issued.
# Library After Issuing: ['Arsene', 'True Detective', 'The Gentleman thief', 'Matermind']
# ['Arsene', 'True Detective', 'The Gentleman thief', 'Matermind', 'Lupin']
# ['Arsene', 'True Detective', 'The Gentleman thief', 'Matermind', 'Lupin']
# ['Arsene', 'Lupin', 'Matermind', 'The Gentleman thief', 'True Detective']

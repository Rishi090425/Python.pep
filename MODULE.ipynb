# %%
import random

print(random.randint(1,10))
print(random.choice(['Python','SQL','Power BI']))
# Out:
# 2
# Power BI

# %%
import statistics

marks=[75,80,67,65,43]
print(statistics.mean(marks))
print(statistics.median(marks))
# Out:
# 66
# 67

# %%
import math

print(math.pow(2, 3))
# Out:
# 8.0

# %%
print("Calculator Module Loaded")
def add(a,b):
    return a+b
# Out:
# Calculator Module Loaded
